# %% [markdown]
# <a href="https://colab.research.google.com/github/Maulana-553/PembelajaranMesin/blob/main/Tugas_Pertemuan_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
dataset = '/content/drive/MyDrive/Pembelajaran Mesin/bwf_historic_rankings.csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#         Unnamed: 0    country        date draw  rank  points  \
# 0                0    DENMARK  2023-10-23   MS     1  107455
# 1                1  INDONESIA  2023-10-23   MS     2   86611
# 2                2      JAPAN  2023-10-23   MS     3   82015
# 3                3   THAILAND  2023-10-23   MS     4   79778
# 4                4      CHINA  2023-10-23   MS     5   78548
# ...            ...        ...         ...  ...   ...     ...
# 859995      859995    ENGLAND  1990-01-01   XD    96    4920
# 859996      859996  AUSTRALIA  1990-01-01   XD    97    4900
# 859997      859997      CHINA  1990-01-01   XD    98    4900
# 859998      859998  AUSTRALIA  1990-01-01   XD    99    4900
# 859999      859999      KOREA  1990-01-01   XD   100    4880
#
#                                           name
# 0                               VIKTOR AXELSEN
# 1                     ANTHONY SINISUKA GINTING
# 2                                KODAI NARAOKA
# ...

# %%
data.head()
# Out:
#    Unnamed: 0    country        date draw  rank  points  \
# 0           0    DENMARK  2023-10-23   MS     1  107455
# 1           1  INDONESIA  2023-10-23   MS     2   86611
# 2           2      JAPAN  2023-10-23   MS     3   82015
# 3           3   THAILAND  2023-10-23   MS     4   79778
# 4           4      CHINA  2023-10-23   MS     5   78548
#
#                        name
# 0            VIKTOR AXELSEN
# 1  ANTHONY SINISUKA GINTING
# 2             KODAI NARAOKA
# 3        KUNLAVUT VITIDSARN
# 4                LI SHIFENG

# %%
print(data.dtypes)
# Out:
# Unnamed: 0     int64
# country       object
# date          object
# draw          object
# rank           int64
# points         int64
# name          object
# dtype: object

# %%
datanoid = data.drop(data.columns[4],axis=1)

# %%
datanoid
# Out:
#         Unnamed: 0    country        date draw  points  \
# 0                0    DENMARK  2023-10-23   MS  107455
# 1                1  INDONESIA  2023-10-23   MS   86611
# 2                2      JAPAN  2023-10-23   MS   82015
# 3                3   THAILAND  2023-10-23   MS   79778
# 4                4      CHINA  2023-10-23   MS   78548
# ...            ...        ...         ...  ...     ...
# 859995      859995    ENGLAND  1990-01-01   XD    4920
# 859996      859996  AUSTRALIA  1990-01-01   XD    4900
# 859997      859997      CHINA  1990-01-01   XD    4900
# 859998      859998  AUSTRALIA  1990-01-01   XD    4900
# 859999      859999      KOREA  1990-01-01   XD    4880
#
#                                           name
# 0                               VIKTOR AXELSEN
# 1                     ANTHONY SINISUKA GINTING
# 2                                KODAI NARAOKA
# 3                           KUNLAVUT VITIDSARN
# 4                                   LI SHIFENG
# ...

# %%
data.describe()
# Out:
#           Unnamed: 0           rank         points
# count  860000.000000  860000.000000  860000.000000
# mean   429999.500000      50.500000   24409.316090
# std    248260.760089      28.866087   17174.074006
# min         0.000000       1.000000    3850.000000
# 25%    214999.750000      25.750000   12080.000000
# 50%    429999.500000      50.500000   19280.000000
# 75%    644999.250000      75.250000   31350.000000
# max    859999.000000     100.000000  122606.000000

# %%
data.loc[:,"rank":].corr()
# Out:
# <ipython-input-15-056b5a6e9737>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.loc[:,"rank":].corr()
#             rank    points
# rank    1.000000 -0.779284
# points -0.779284  1.000000

# %% [markdown]
# # Rank vs Points

# %%
from matplotlib import pyplot as plt
data.plot(kind='scatter', x='rank', y='points', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # Dengan API

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-c1736d51-ae14-400c-97dc-377d6f2e5376" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1736d51-ae14-400c-97dc-377d6f2e5376">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "badminton"
# Out:
# ...
# ref                                                              title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# ---------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# sanderp/badminton-bwf-world-tour                                 Badminton BWF World Tour                              2MB  2021-04-07 10:41:18           1016         16  0.9705882
# tejasurya/thomas-cup-2022-badminton-tweets                       🏸Thomas Cup 2022 Badminton Tweets                     2MB  2022-06-20 19:22:23            382         20  1.0
# valentindefour/badminton-world-rankings-updated-august-2020      Badminton World Rankings (historic Top 100)          10MB  2023-11-04 11:12:56            551         14  0.9411765
# ...

# %%
# !kaggle datasets download mathurinache/badminton-at-the-summer-olympics
# Out:
# ...
#   0% 0.00/343 [00:00<?, ?B/s]
# 100% 343/343 [00:00<00:00, 738kB/s]

# %%
# !unzip /content/badminton-at-the-summer-olympics.zip
# Out:
# Archive:  /content/badminton-at-the-summer-olympics.zip
#   inflating: Badminton_at_the_Summer_Olympics.csv

# %%
import pandas as pd

pd.read_csv('/content//Badminton_at_the_Summer_Olympics.csv')
# Out:
#              Event   72   76   80   84   88   92   96   00   04   08   12  \
# 0  Current program  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    Men's singles  (d)  NaN  (e)    X    X    X    X    X    X    X    X
# 2    Men's doubles  (d)  NaN  (e)    X    X    X    X    X    X    X    X
# 3  Women's singles  (d)  NaN  (e)    X    X    X    X    X    X    X    X
# 4  Women's doubles  NaN  NaN  (e)    X    X    X    X    X    X    X    X
# 5    Mixed doubles  (d)  NaN  (e)  NaN    X    X    X    X    X    X    X
# 6           Events    0  0.0    0    0    5    4    5    5    5    5    5
#
#     16   20
# 0  NaN  NaN
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN
# 5  NaN  NaN
# 6  5.0  5.0
